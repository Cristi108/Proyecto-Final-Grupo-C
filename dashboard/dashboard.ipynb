# %%
import pandas as pd
import plotly.express as px

data = {
    'años': [2018, 2019, 2020, 2021, 2022],
    'comercial': [65, 65, 60, 58, 60],
    'industrial': [7, 7, 6, 5, 6],
    'gobierno': [37, 37, 37, 37, 37],
    'residencial': [317, 324, 330, 336, 341]
}

df = pd.DataFrame(data)


df_long = df.melt(id_vars='años',
                  var_name='tipo de consumo',
                  value_name='valor')

fig = px.scatter(
    df_long,
    x='años',
    y='valor',
    color='tipo de consumo',
    size='valor',
    hover_name='tipo de consumo',
    size_max=50,
    labels={"valor": "Consumo"}  # renombra eje y
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="778a52e7-35a3-452b-aa97-63d7325395cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("778a52e7-35a3-452b-aa97-63d7325395cb")) {                    Plotly.newPlot(                        "778a52e7-35a3-452b-aa97-63d7325395cb",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003etipo de consumo=comercial\u003cbr\u003eaños=%{x}\u003cbr\u003eConsumo=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["comercial","comercial","comercial","comercial","comercial"],"legendgroup":"comercial","marker":{"color":"#636efa","size":[65,65,60,58,60],"sizemode":"area","sizeref":0.1364,"symbol":"circle"},"mode":"markers","name":"comercial","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022],"xaxis":"x","y":[65,65,60,58,60],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003etipo de consumo=industrial\u003cbr\u003eaños=%{x}\u003cbr\u003eConsumo=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["industrial","industrial","industrial","industrial","industrial"],"legendgroup":"industrial","marker":{"color":"#EF553B","size":[7,7,6,5,6],"sizemode":"area","sizeref":0.1364,"symbol":"circle"},"mode":"markers","name":"industrial","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022],"xaxis":"x","y":[7,7,6,5,6],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003etipo de consumo=gobierno\u003cbr\u003eaños=%{x}\u003cbr\u003eConsumo=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["gobierno","gobierno","gobierno","gobierno","gobierno"],"legendgroup":"gobierno","marker":{"color":"#00cc96","size":[37,37,37,37,37],"sizemode":"area","sizeref":0.1364,"symbol":"circle"},"mode":"markers","name":"gobierno","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022],"xaxis":"x","y":[37,37,37,37,37],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003etipo de consumo=residencial\u003cbr\u003eaños=%{x}\u003cbr\u003eConsumo=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["residencial","residencial","residencial","residencial","residencial"],"legendgroup":"residencial","marker":{"color":"#ab63fa","size":[317,324,330,336,341],"sizemode":"area","sizeref":0.1364,"symbol":"circle"},"mode":"markers","name":"residencial","orientation":"v","showlegend":true,"x":[2018,2019,2020,2021,2022],"xaxis":"x","y":[317,324,330,336,341],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.333333333333333 ...

# %%
import pandas as pd
import plotly.express as px

data = {
    'Años': [2018, 2019, 2020, 2021, 2022],
    'TOTAL':[718.8,708.1,720.9,717.8,735.8],
    'Panamá': [378.3,369.7,379.8,370.7,373.9],
    'Panamá Oeste': [120.7,125.2,125.5,125.9,133.8],
    'Veraguas': [21.6,21.7,21.8,24.0,26.2],
    'Los Santos': [11.8,12.4,12.3,12.7,12.7],
    'Herrera': [14.0,14.3,14.2,15.1,14.6],
    'Darién': [14.0,14.3,14.2,15.1,14.6],
    'Chiriquí': [61.5,49.2,49.7,48.1,55.6],
    'Coclé': [19.9,22.3,22.2,22.6,23.4],
    'Colón': [69.3,66.9,67.8,69.7,67.9],
    'Bocas del Toro': [20.1,22.4,23.2,25.1,23.4],
}

df = pd.DataFrame(data)


df_long = df.melt(
    id_vars='Años',
    var_name='Provincia',
    value_name='valor'
)


fig = px.bar(
    df_long,
    x='Años',
    y='valor',
    color='valor',
    color_continuous_scale='Tealrose',
    facet_col='Provincia',
    facet_col_wrap=4,
    title="Consumo de agua por Provincia ",
    labels={"valor": "Datos de agua"}
)

fig.update_layout(
    coloraxis_colorbar=dict(
        title="Valor",
        thickness=15
    ),
    showlegend=False
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b4bc1ec3-c2e5-4929-8e00-1c89412e706f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4bc1ec3-c2e5-4929-8e00-1c89412e706f")) {                    Plotly.newPlot(                        "b4bc1ec3-c2e5-4929-8e00-1c89412e706f",                        [{"alignmentgroup":"True","hovertemplate":"Provincia=TOTAL\u003cbr\u003eAños=%{x}\u003cbr\u003eDatos de agua=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[718.8,708.1,720.9,717.8,735.8],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2018,2019,2020,2021,2022],"xaxis":"x9","y":[718.8,708.1,720.9,717.8,735.8],"yaxis":"y9","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Provincia=Panamá\u003cbr\u003eAños=%{x}\u003cbr\u003eDatos de agua=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[378.3,369.7,379.8,370.7,373.9],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2018,2019,2020,2021,2022],"xaxis":"x10","y":[378.3,369.7,379.8,370.7,373.9],"yaxis":"y10","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Provincia=Panamá Oeste\u003cbr\u003eAños=%{x}\u003cbr\u003eDatos de agua=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[120.7,125.2,125.5,125.9,133.8],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2018,2019,2020,2021,2022],"xaxis":"x11","y":[120.7,125.2,125.5,125.9,133.8],"yaxis":"y11","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Provincia=Veraguas\u003cbr\u003eAños=%{x}\u003cbr\u003eDatos de agua=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[21.6,21.7,21.8,24.0,26.2],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2018,2019,2020,2021,2022],"xaxis":"x12","y":[21.6,21.7,21.8,24.0,26.2],"yaxis":"y12","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Provincia=Los Santos\u003cbr\u003eAños=%{x}\u003cbr\u003eDatos de agua=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[11.8,12.4,12.3,12.7,12.7],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2018,2019,2020,2021,2022],"xaxis":"x5","y":[11.8,12.4,12.3,12.7,12.7],"yaxis":"y5","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Provincia=Herrera\u003cbr\u003eAños=%{x}\u003cbr\u003eDatos de agua=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[14.0,14.3,14.2,15.1,14.6],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2018,2019,2020,2021,2022],"xaxis":"x6","y":[14.0,14.3,14.2,15.1,14.6],"yaxis":"y6","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Provincia=Darién\u003cbr\u003eAños=%{x}\u003cbr\u003eDatos de agua=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[14.0,14.3,14.2,15.1,14.6],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[2018,2019,2020,2021,2022],"xaxis":"x7","y":[14.0,14.3,14.2,15.1,14.6],"yaxis":"y7","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Provincia=Chiriquí\u003cbr\u003eAños=%{x}\u003cbr\u003eDatos de agua=%{marker.color}\u003cextra\u0 ...

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go


data = {
    'Año': [2018, 2019, 2020, 2021, 2022],
    'Amibiasis': [3858, 4306, 1856, 2362, 2457],
    'Diarrea': [257817, 277872, 102743, 118274, 174603],
    'Giardiasis': [96923, 100992, 2061, 44336, 63073],
    'Hepatitis A': [0, 0, 39, 7, 0],
    'Intoxicación alimentaria': [1298, 1149, 717, 1067, 1433],
    'Salmonellosis': [49, 39, 20, 43, 27],
    'Shigelosis': [30, 26, 0, 13, 33]
}
df = pd.DataFrame(data)
df_long = df.melt(id_vars='Año', var_name='Enfermedad', value_name='Casos')

provincias = pd.DataFrame({
    'Provincia': ['Panamá', 'Panamá Oeste', 'Chiriquí', 'Colón', 'Coclé'],
    'Casos': [150000, 90000, 70000, 45000, 30000]
})

comarcas = pd.DataFrame({
    'Comarca': ['Guna Yala', 'Ngäbe-Buglé', 'Emberá-Wounaan'],
    'Casos': [25000, 40000, 12000]
})


fig = go.Figure()


for enfermedad in df_long["Enfermedad"].unique():
    df_temp = df_long[df_long["Enfermedad"] == enfermedad]
    fig.add_trace(go.Bar(
        x=df_temp["Casos"],
        y=df_temp["Año"],
        name=enfermedad,
        orientation="h",
        visible=True
    ))

t1 = len(fig.data)

df_enf = df_long.groupby("Enfermedad")["Casos"].sum().reset_index()
for i, row in df_enf.iterrows():
    fig.add_trace(go.Bar(
        x=[row["Casos"]],
        y=[row["Enfermedad"]],
        name=row["Enfermedad"],
        orientation="h",
        visible=False
    ))

t2 = len(fig.data) - t1

# -------- 3. BARRAS POR PROVINCIA --------
for i, row in provincias.iterrows():
    fig.add_trace(go.Bar(
        x=[row["Casos"]],
        y=[row["Provincia"]],
        name=row["Provincia"],
        orientation="h",
        visible=False
    ))

t3 = len(fig.data) - (t1 + t2)

# -------- 4. BARRAS POR COMARCA --------
for i, row in comarcas.iterrows():
    fig.add_trace(go.Bar(
        x=[row["Casos"]],
        y=[row["Comarca"]],
        name=row["Comarca"],
        orientation="h",
        visible=False
    ))

t4 = len(fig.data) - (t1 + t2 + t3)

fig.update_layout(
    updatemenus=[
        dict(
            buttons=[
                dict(
                    label="Por Año",
                    method="update",
                    args=[{"visible":
                           [True]*t1 + [False]*(t2+t3+t4)},
                          {"title": "Casos por Año"}]
                ),
                dict(
                    label="Por Enfermedad",
                    method="update",
                    args=[{"visible":
                           [False]*t1 + [True]*t2 + [False]*(t3+t4)},
                          {"title": "Casos por Enfermedad"}]
                ),
                dict(
                    label="Por Provincia",
                    method="update",
                    args=[{"visible":
                           [False]*(t1+t2) + [True]*t3 + [False]*t4},
                          {"title": "Casos por Provincia"}]
                ),
                dict(
                    label="Por Comarca",
                    method="update",
                    args=[{"visible":
                           [False]*(t1+t2+t3) + [True]*t4},
                          {"title": "Casos por Comarca"}]
                )
            ],
            x=0.1,
            y=1.1,
            direction="down"
        )
    ],
    height=600,
    title="Dashboard Interactivo de Enfermedades Hídroalimentarias"
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5ea0826e-08e7-48a9-a80e-a7505381ae3d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5ea0826e-08e7-48a9-a80e-a7505381ae3d")) {                    Plotly.newPlot(                        "5ea0826e-08e7-48a9-a80e-a7505381ae3d",                        [{"name":"Amibiasis","orientation":"h","visible":true,"x":[3858,4306,1856,2362,2457],"y":[2018,2019,2020,2021,2022],"type":"bar"},{"name":"Diarrea","orientation":"h","visible":true,"x":[257817,277872,102743,118274,174603],"y":[2018,2019,2020,2021,2022],"type":"bar"},{"name":"Giardiasis","orientation":"h","visible":true,"x":[96923,100992,2061,44336,63073],"y":[2018,2019,2020,2021,2022],"type":"bar"},{"name":"Hepatitis A","orientation":"h","visible":true,"x":[0,0,39,7,0],"y":[2018,2019,2020,2021,2022],"type":"bar"},{"name":"Intoxicación alimentaria","orientation":"h","visible":true,"x":[1298,1149,717,1067,1433],"y":[2018,2019,2020,2021,2022],"type":"bar"},{"name":"Salmonellosis","orientation":"h","visible":true,"x":[49,39,20,43,27],"y":[2018,2019,2020,2021,2022],"type":"bar"},{"name":"Shigelosis","orientation":"h","visible":true,"x":[30,26,0,13,33],"y":[2018,2019,2020,2021,2022],"type":"bar"},{"name":"Amibiasis","orientation":"h","visible":false,"x":[14839],"y":["Amibiasis"],"type":"bar"},{"name":"Diarrea","orientation":"h","visible":false,"x":[931309],"y":["Diarrea"],"type":"bar"},{"name":"Giardiasis","orientation":"h","visible":false,"x":[307385],"y":["Giardiasis"],"type":"bar"},{"name":"Hepatitis A","orientation":"h","visible":false,"x":[46],"y":["Hepatitis A"],"type":"bar"},{"name":"Intoxicación alimentaria","orientation":"h","visible":false,"x":[5664],"y":["Intoxicación alimentaria"],"type":"bar"},{"name":"Salmonellosis","orientation":"h","visible":false,"x":[178],"y":["Salmonellosis"],"type":"bar"},{"name":"Shigelosis","orientation":"h","visible":false,"x":[102],"y":["Shigelosis"],"type":"bar"},{"name":"Panamá","orientation":"h","visible":false,"x":[150000],"y":["Panamá"],"type":"bar"},{"name":"Panamá Oeste","orientation":"h","visible":false,"x":[90000],"y":["Panamá Oeste"],"type":"bar"},{"name":"Chiriquí","orientation":"h","visible":false,"x":[70000],"y":["Chiriquí"],"type":"bar"},{"name":"Colón","orientation":"h","visible":false,"x":[45000],"y":["Colón"],"type":"bar"},{"name":"Coclé","orientation":"h","visible":false,"x":[30000],"y":["Coclé"],"type":"bar"},{"name":"Guna Yala","orientation":"h","visible":false,"x":[25000],"y":["Guna Yala"],"type":"bar"},{"name":"Ngäbe-Buglé","orientation":"h","visible":false,"x":[40000],"y":["Ngäbe-Buglé"],"type":"bar"},{"name":"Emberá-Wounaan","orientation":"h","visible":false,"x":[12000],"y":["Emberá-Wounaan"],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...
